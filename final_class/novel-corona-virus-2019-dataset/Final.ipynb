# %%
import pandas as pd

# %%
covid = pd.read_csv('COVID19_open_line_list.csv')

# %%
covid
# Out:
#         ID  age     sex                        city province country  \
# 0      1.0   30    male     Chaohu City, Hefei City    Anhui   China
# 1      2.0   47    male  Baohe District, Hefei City    Anhui   China
# 2      3.0   49    male  High-Tech Zone, Hefei City    Anhui   China
# 3      4.0   47  female  High-Tech Zone, Hefei City    Anhui   China
# 4      5.0   50  female  Feidong County, Hefei City    Anhui   China
# ...    ...  ...     ...                         ...      ...     ...
# 14121  NaN  NaN     NaN                         NaN      NaN     NaN
# 14122  NaN  NaN     NaN                         NaN      NaN     NaN
# 14123  NaN  NaN     NaN                         NaN      NaN     NaN
# 14124  NaN  NaN     NaN                         NaN      NaN     NaN
# 14125  NaN  NaN     NaN                         NaN      NaN     NaN
#
#        wuhan(0)_not_wuhan(1)   latitude   longitude geo_resolution  ...  \
# ...

# %%
covid.describe()
# Out:
#                  ID  wuhan(0)_not_wuhan(1)      latitude     longitude  \
# count  13173.000000                13170.0  13147.000000  13147.000000
# mean    6769.250436                    1.0     31.994650    110.495353
# std     3920.886020                    0.0      7.536335     27.985144
# min        1.000000                    1.0    -37.813600   -124.953070
# 25%     3351.000000                    1.0     27.905380    111.729600
# 50%     6865.000000                    1.0     31.759410    115.441800
# 75%    10180.000000                    1.0     35.781340    120.440400
# max    13479.000000                    1.0     69.649468    153.400000
#
#        chronic_disease_binary  Unnamed: 33  Unnamed: 34  Unnamed: 35  \
# count               18.000000          0.0          0.0          0.0
# mean                 0.722222          NaN          NaN          NaN
# std                  0.460889          NaN          NaN          NaN
# ...

# %%
covid.isna().mean()
# Out:
# ID                          0.067464
# age                         0.904502
# sex                         0.910520
# city                        0.278352
# province                    0.086366
# country                     0.069234
# wuhan(0)_not_wuhan(1)       0.067677
# latitude                    0.069305
# longitude                   0.069305
# geo_resolution              0.069305
# date_onset_symptoms         0.947190
# date_admission_hospital     0.948322
# date_confirmation           0.073411
# symptoms                    0.965100
# lives_in_Wuhan              0.960003
# travel_history_dates        0.964392
# travel_history_location     0.946340
# reported_market_exposure    0.997522
# additional_information      0.829251
# chronic_disease_binary      0.998726
# chronic_disease             0.999080
# source                      0.083251
# sequence_available          0.999929
# outcome                     0.986974
# date_death_or_discharge     0.993416
# ...

# %%
covid['province'].value_counts()
# Out:
# Guangdong       1228
# Zhejiang        1074
# Henan           1036
# Hunan            884
# Jiangxi          805
#                 ...
# Markazi            1
# Kedah              1
# North Jeolla       1
# Shizuoka           1
# Wisconsin          1
# Name: province, Length: 150, dtype: int64

# %%
covid19 = pd.read_csv('covid_19_data.csv')
covid19
# Out:
#        SNo ObservationDate                        Province/State  \
# 0        1      01/22/2020                                 Anhui
# 1        2      01/22/2020                               Beijing
# 2        3      01/22/2020                             Chongqing
# 3        4      01/22/2020                                Fujian
# 4        5      01/22/2020                                 Gansu
# ...    ...             ...                                   ...
# 4242  4243      03/08/2020                    Northern Territory
# 4243  4244      03/08/2020  Lackland, TX (From Diamond Princess)
# 4244  4245      03/08/2020                 Montgomery County, TX
# 4245  4246      03/08/2020     Omaha, NE (From Diamond Princess)
# 4246  4247      03/08/2020    Travis, CA (From Diamond Princess)
#
#       Country/Region          Last Update  Confirmed  Deaths  Recovered
# 0     Mainland China      1/22/2020 17:00        1.0     0.0        0.0
# ...

# %% [markdown]
# ### What is the average age of the male and female patients?
